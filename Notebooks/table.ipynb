# %% [markdown]
# https://www.kaggle.com/berkayalan/vaccinations-in-united-states
# us_vaccinations.csv

# %% [markdown]
# # The main goal of this dashboard is to display the pogress of vaccinations in the 52 United states

# %% [markdown]
# ## in this notebook I will eplore the best way to display the data. Later I will make a django app where I am aiming to display the following views:
# * A heatmap of the united states to keep track of the amount of vacinnations in each state
# * A linechart for each state filtered by state and date to diaplay the change in vaccinations
# * A bar chart of pie chart to display the amount of people vaccinted compared to the total population per state
#
# *Seaborn: Size of the state == box --> vaccination vs total population filling up the box

# %% [markdown]
# # Imports

# %%
import pandas as pd
import sqlite3 as sql
from bokeh.io import push_notebook, output_notebook 
from bokeh.plotting import figure,show
from bokeh.embed import components
from bokeh.models import ColumnDataSource, HoverTool,Legend
from bokeh.palettes import Plasma
from bokeh.transform import factor_cmap

# %%
output_notebook() #to see notebook in the app
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Opening dataset that contains vaccine information per state

# %%
def table():
    db = '../dash/project_2.db'
    conn = sql.connect(db)
    total = pd.read_sql("SELECT * from total", conn, index_col='index')
    total = total[['state', 'location', 'perc_daily_vacc_pop']].sort_values('perc_daily_vacc_pop',ascending=False).reset_index(drop=True)
    return total

table()
# Out:
#    state              location  perc_daily_vacc_pop
# 0     VT               Vermont                   61
# 1     MA         Massachusetts                   58
# 2     DC  District of Columbia                   57
# 3     CT           Connecticut                   56
# 4     ME                 Maine                   54
# 5     HI                Hawaii                   54
# 6     RI          Rhode Island                   53
# 7     NH         New Hampshire                   51
# 8     MD              Maryland                   50
# 9     WA            Washington                   50
# 10    NJ            New Jersey                   50
# 11    NM            New Mexico                   50
# 12    NY        New York State                   49
# 13    OR                Oregon                   49
# 14    PA          Pennsylvania                   49
# 15    VA              Virginia                   49
# 16    CA            California                   49
# 17    DE              Delaware                   48
# 18    CO              Colorado                   48
# 19    MN             Minnesota                   47
# 20    IL              Illinois                   46
# 21    WI             Wisconsin                   46
# 22    IA                  Iowa                   44
# 23    FL               Florida                   44
# 24    MI              Michigan                   43
# 25    OH                  Ohio                   42
# 26    SD          South Dakota                   42
# 27    PR           Puerto Rico                   42
# 28    AZ               Arizona                   42
# 29    NE              Nebraska                   42
# 30    AK                Alaska                   41
# 31    NV                Nevada                   40
# 32    KY              Kentucky                   40
# 33    TX                 Texas                   39
# 34    UT                  Utah                   39
# 35    MT               Montana                   39
# 36    NC        North Carolina                   39
# 37    KS                Kansas                   39
# 38    ND          North Dakota                   37
# 39    SC        South Carolina                   37
# 40    MO              Missouri                   37
# 41    IN               Indiana                   37
# 42    OK              Oklahoma                   36
# 43    GA               Georgia                   36
# 44    AR              Arkansas                   36
# 45    WV         West Virginia                   35
# 46    TN             Tennessee                   34
# 47    WY               Wyoming                   34
# 48    ID                 Idaho                   33
# 49    LA             Louisiana                   32
# 50    MS           Mississippi                   30
# 51    AL               Alabama                   29
